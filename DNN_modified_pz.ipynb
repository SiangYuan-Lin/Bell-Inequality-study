# %%
# %reset -sf

from time import time
time_start = time()

import pandas as pd
import numpy as np
import scipy as sp
import gc
import os

os.environ['TF_CPP_MIN_LOG_LEVEL'] = '1' # suppress tensorflow imformation messages

from sklearn.preprocessing import MinMaxScaler, RobustScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

import tensorflow as tf

#from mt2 import mt2

#import get_data as gd
#import atlas_plot as ap
#plot = ap.Plotter()

print(tf.__version__)
print(tf.config.list_physical_devices())
print()
# Out:
# 2.13.0
# [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]

# %%
seed = 42  # set random seed
sampling = int(1e6)
# num_folds = 2
batch_size = 1024
epochs = 512
learning_rate = 3e-6

# %%
np.random.seed(seed)
processor = gd.DataProcessor(sampling=sampling, processor=10)
path = "/root/data/truth/signal/*npz"
processor.load_files(path)
data = gd.Data(*processor.files)
# print(dir(data))
# Out:
# Number of available processors: 128
# Number of used processors: 10
#
# ['/root/data/truth/signal/CGLMP.npz', '/root/data/truth/signal/Higgs.npz', '/root/data/truth/signal/LeadLepton.npz', '/root/data/truth/signal/LeptonM.npz', '/root/data/truth/signal/LeptonP.npz', '/root/data/truth/signal/LmNu.npz', '/root/data/truth/signal/LpNu.npz', '/root/data/truth/signal/MET.npz', '/root/data/truth/signal/WmBoson.npz', '/root/data/truth/signal/WpBoson.npz', '/root/data/truth/signal/diLepton.npz', '/root/data/truth/signal/subLeadLepton.npz', '/root/data/truth/signal/xi_xyz.npz']

# %%
GEV = 1e3

cut_pre_pt_lead = data.LeadLep["pt"] > 22 * GEV
cut_pre_pt_sub = data.SubLep["pt"] > 15 * GEV
cut_pre_dilep_m = data.diLep["m"] > 10 * GEV
cut_pre_pt_miss = data.MET["pt"] > 20 * GEV
cut_pre = cut_pre_pt_lead & cut_pre_pt_sub & cut_pre_dilep_m & cut_pre_pt_miss

del (cut_pre_pt_lead, cut_pre_pt_sub, cut_pre_dilep_m, cut_pre_pt_miss)

# %%
# inputs -> observed params
lep_p = processor.process_part(data.LepP)
lep_m = processor.process_part(data.LepM)
lep_kin = pd.concat([lep_p.iloc[:,:4], lep_m.iloc[:,:4]], axis=1)
MET = processor.process_MET(data.MET)
dilep_kin = processor.process_dipart(data.LepP, data.LepM)
# mt = np.sqrt(
#     mt2(
#         lep_m["m"],
#         lep_m["px"],
#         lep_m["py"],  # Visible 1: mass, px, py
#         lep_p["m"],
#         lep_p["px"],
#         lep_p["py"],  # Visible 2: mass, px, py
#         MET["MET_px"],
#         MET["MET_py"],  # Missing transverse momentum: x, y
#         0,
#         0,  # Invisible 1 mass, invisible 2 mass
#     )
# )
# vx = 5 * pd.DataFrame({"vx": mt + 0.3 * np.sqrt(dilep_kin["m"])})
# dilep_kin.iloc[:, 0:4]
obs_kin = pd.concat([MET.iloc[:, 1:3], lep_kin], axis=1)[cut_pre]
print("obs_kin shape:", obs_kin.shape)
print(obs_kin.head(3))
print()

# targets -> interested unknowns
int_kin = pd.DataFrame(processor.process_dipart(data.NuP, data.NuM)[["pz"]])[cut_pre]
print("int_kin shape:", int_kin.shape)
print(int_kin.head(3))
print()

del (processor, lep_p, lep_m, MET, dilep_kin)
gc.collect()
# Out:
# obs_kin shape: (1378510, 10)
#        MET_px     MET_py           E         px         py          pz  \
# 7   96.335650  47.095450   19.500895  -4.561588  18.924410   -1.154271
# 9  -26.992604 -70.883859  164.814766  34.397141   2.031300 -161.172625
# 10  44.222846 -15.383637   47.669113 -26.605045 -17.256748   35.590859
#
#             E         px         py         pz
# 7   43.361348  42.407754  -4.632000   7.767462
# 9   70.592648  29.001777   1.896990 -64.332027
# 10  90.238664 -23.868604  32.986602  80.530680
#
# int_kin shape: (1378510, 1)
#             pz
# 7  -105.565620
# 9  -170.813820
# 10   92.722389
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/pandas/core/arraylike.py:396: RuntimeWarning: invalid value encountered in sqrt
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# 0

# %%
SCALAR_int_ru = RobustScaler()
int_kin = SCALAR_int_ru.fit_transform(int_kin)
SCALAR_int_mm = MinMaxScaler()
int_kin = SCALAR_int_mm.fit_transform(int_kin)

SCALAR_obs_ru = RobustScaler()
obs_kin = SCALAR_obs_ru.fit_transform(obs_kin)
SCALAR_obs_mm = MinMaxScaler()
obs_kin = SCALAR_obs_mm.fit_transform(obs_kin)

# %%
# Define a new activation function
def custom_activation(x):
    return x*tf.keras.backend.sigmoid(x)

# Define the model.
def build_model():
    # Input layer
    inputs = tf.keras.layers.Input(shape=(train_x.shape[-1],))
    x = tf.keras.layers.Flatten()(inputs)

    # Hidden tf.keras.layers
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    x = tf.keras.layers.Dense(units=16, activation="elu")(x)
    x = tf.keras.layers.Dropout(rate=0.1)(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    x = tf.keras.layers.Dense(units=4, activation="elu")(x)
    
    # Last dense layer
    outputs = tf.keras.layers.Dense(units=train_y.shape[-1], activation="sigmoid")(x)

    # Compile model
    model = tf.keras.Model(inputs=inputs, outputs=outputs)
    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=learning_rate),
        loss="mse",
    )

    # Summarize the model
    model.summary()

    return model

# %%
model = build_model()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_3 (InputLayer)        [(None, 10)]              0
#
#  flatten_2 (Flatten)         (None, 10)                0
#
#  dense_10 (Dense)            (None, 16)                176
#
#  dense_11 (Dense)            (None, 16)                272
#
#  dropout_2 (Dropout)         (None, 16)                0
#
#  dense_12 (Dense)            (None, 4)                 68
#
#  dense_13 (Dense)            (None, 4)                 20
#
#  dense_14 (Dense)            (None, 1)                 5
#
# =================================================================
# Total params: 541 (2.11 KB)
# Trainable params: 541 (2.11 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
stop_early = tf.keras.callbacks.EarlyStopping(
    monitor="val_loss",
    min_delta=1e-6,
    patience=10,
    mode="auto",
    baseline=None,
    restore_best_weights=False,
)

# Fit the model
history = model.fit(
    x=train_x,
    y=train_y,
    validation_data=(valid_x, valid_y),
    epochs=epochs,
    batch_size=batch_size,
    verbose=2,
    callbacks=[stop_early],
)
# Out:
# Epoch 1/512
# 539/539 - 4s - loss: 0.0204 - val_loss: 0.0195 - 4s/epoch - 7ms/step
# Epoch 2/512
# 539/539 - 2s - loss: 0.0171 - val_loss: 0.0163 - 2s/epoch - 4ms/step
# Epoch 3/512
# 539/539 - 2s - loss: 0.0141 - val_loss: 0.0133 - 2s/epoch - 4ms/step
# Epoch 4/512
# 539/539 - 2s - loss: 0.0114 - val_loss: 0.0107 - 2s/epoch - 4ms/step
# Epoch 5/512
# 539/539 - 2s - loss: 0.0091 - val_loss: 0.0084 - 2s/epoch - 4ms/step
# Epoch 6/512
# 539/539 - 2s - loss: 0.0071 - val_loss: 0.0064 - 2s/epoch - 4ms/step
# Epoch 7/512
# 539/539 - 2s - loss: 0.0055 - val_loss: 0.0048 - 2s/epoch - 4ms/step
# Epoch 8/512
# 539/539 - 2s - loss: 0.0042 - val_loss: 0.0036 - 2s/epoch - 4ms/step
# Epoch 9/512
# 539/539 - 2s - loss: 0.0032 - val_loss: 0.0027 - 2s/epoch - 4ms/step
# Epoch 10/512
# 539/539 - 2s - loss: 0.0025 - val_loss: 0.0020 - 2s/epoch - 4ms/step
# Epoch 11/512
# 539/539 - 2s - loss: 0.0020 - val_loss: 0.0016 - 2s/epoch - 4ms/step
# Epoch 12/512
# 539/539 - 2s - loss: 0.0018 - val_loss: 0.0014 - 2s/epoch - 4ms/step
# Epoch 13/512
# 539/539 - 2s - loss: 0.0017 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 14/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 15/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 16/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 17/512
# 539/539 - 2s - loss: 0.0016 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 18/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 19/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 20/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 21/512
# 539/539 - 2s - loss: 0.0015 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 22/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 0.0013 - 2s/epoch - 4ms/step
# Epoch 23/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 24/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 25/512
# 539/539 - 2s - loss: 0.0014 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 26/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 27/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 28/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 29/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 30/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 31/512
# 539/539 - 2s - loss: 0.0013 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 32/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 33/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 34/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 35/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 36/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 37/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 38/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 39/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 40/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0012 - 2s/epoch - 4ms/step
# Epoch 41/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 42/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 43/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 44/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 45/512
# 539/539 - 2s - loss: 0.0012 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 46/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 47/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 48/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 49/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 50/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 51/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 52/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 53/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 54/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 55/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 56/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 57/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 58/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 59/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 60/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 61/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 62/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 63/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 64/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 65/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 66/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 67/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0011 - 2s/epoch - 4ms/step
# Epoch 68/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 69/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 70/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 71/512
# 539/539 - 2s - loss: 0.0011 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 72/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 73/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 74/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 75/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 76/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 77/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 0.0010 - 2s/epoch - 4ms/step
# Epoch 78/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 9.9508e-04 - 2s/epoch - 4ms/step
# Epoch 79/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 9.8832e-04 - 2s/epoch - 4ms/step
# Epoch 80/512
# 539/539 - 2s - loss: 0.0010 - val_loss: 9.8174e-04 - 2s/epoch - 4ms/step
# Epoch 81/512
# 539/539 - 2s - loss: 9.9932e-04 - val_loss: 9.7595e-04 - 2s/epoch - 4ms/step
# Epoch 82/512
# 539/539 - 2s - loss: 9.9246e-04 - val_loss: 9.6803e-04 - 2s/epoch - 4ms/step
# Epoch 83/512
# 539/539 - 2s - loss: 9.8659e-04 - val_loss: 9.6133e-04 - 2s/epoch - 4ms/step
# Epoch 84/512
# 539/539 - 2s - loss: 9.7964e-04 - val_loss: 9.5430e-04 - 2s/epoch - 4ms/step
# Epoch 85/512
# 539/539 - 2s - loss: 9.7200e-04 - val_loss: 9.4674e-04 - 2s/epoch - 4ms/step
# Epoch 86/512
# 539/539 - 2s - loss: 9.6555e-04 - val_loss: 9.3912e-04 - 2s/epoch - 4ms/step
# Epoch 87/512
# 539/539 - 2s - loss: 9.5836e-04 - val_loss: 9.3133e-04 - 2s/epoch - 4ms/step
# Epoch 88/512
# 539/539 - 2s - loss: 9.5096e-04 - val_loss: 9.2340e-04 - 2s/epoch - 4ms/step
# Epoch 89/512
# 539/539 - 2s - loss: 9.4330e-04 - val_loss: 9.1558e-04 - 2s/epoch - 4ms/step
# Epoch 90/512
# 539/539 - 2s - loss: 9.3610e-04 - val_loss: 9.0803e-04 - 2s/epoch - 4ms/step
# Epoch 91/512
# 539/539 - 2s - loss: 9.2859e-04 - val_loss: 8.9957e-04 - 2s/epoch - 4ms/step
# Epoch 92/512
# 539/539 - 2s - loss: 9.2090e-04 - val_loss: 8.9194e-04 - 2s/epoch - 4ms/step
# Epoch 93/512
# 539/539 - 2s - loss: 9.1238e-04 - val_loss: 8.8451e-04 - 2s/epoch - 4ms/step
# Epoch 94/512
# 539/539 - 2s - loss: 9.0542e-04 - val_loss: 8.7571e-04 - 2s/epoch - 4ms/step
# Epoch 95/512
# 539/539 - 2s - loss: 8.9732e-04 - val_loss: 8.6831e-04 - 2s/epoch - 4ms/step
# Epoch 96/512
# 539/539 - 2s - loss: 8.8895e-04 - val_loss: 8.5957e-04 - 2s/epoch - 4ms/step
# Epoch 97/512
# 539/539 - 2s - loss: 8.8126e-04 - val_loss: 8.5112e-04 - 2s/epoch - 4ms/step
# Epoch 98/512
# 539/539 - 2s - loss: 8.7322e-04 - val_loss: 8.4311e-04 - 2s/epoch - 4ms/step
# Epoch 99/512
# 539/539 - 2s - loss: 8.6446e-04 - val_loss: 8.3425e-04 - 2s/epoch - 4ms/step
# Epoch 100/512
# 539/539 - 2s - loss: 8.5573e-04 - val_loss: 8.2590e-04 - 2s/epoch - 4ms/step
# Epoch 101/512
# 539/539 - 2s - loss: 8.4802e-04 - val_loss: 8.1819e-04 - 2s/epoch - 4ms/step
# Epoch 102/512
# 539/539 - 2s - loss: 8.3905e-04 - val_loss: 8.0907e-04 - 2s/epoch - 4ms/step
# Epoch 103/512
# 539/539 - 2s - loss: 8.3103e-04 - val_loss: 8.0058e-04 - 2s/epoch - 4ms/step
# Epoch 104/512
# 539/539 - 2s - loss: 8.2304e-04 - val_loss: 7.9213e-04 - 2s/epoch - 4ms/step
# Epoch 105/512
# 539/539 - 2s - loss: 8.1435e-04 - val_loss: 7.8472e-04 - 2s/epoch - 4ms/step
# Epoch 106/512
# 539/539 - 2s - loss: 8.0661e-04 - val_loss: 7.7598e-04 - 2s/epoch - 4ms/step
# Epoch 107/512
# 539/539 - 2s - loss: 7.9776e-04 - val_loss: 7.6832e-04 - 2s/epoch - 4ms/step
# Epoch 108/512
# 539/539 - 2s - loss: 7.8984e-04 - val_loss: 7.6025e-04 - 2s/epoch - 4ms/step
# Epoch 109/512
# 539/539 - 2s - loss: 7.8278e-04 - val_loss: 7.5225e-04 - 2s/epoch - 4ms/step
# Epoch 110/512
# 539/539 - 2s - loss: 7.7431e-04 - val_loss: 7.4414e-04 - 2s/epoch - 4ms/step
# Epoch 111/512
# 539/539 - 2s - loss: 7.6707e-04 - val_loss: 7.3655e-04 - 2s/epoch - 4ms/step
# Epoch 112/512
# 539/539 - 2s - loss: 7.5988e-04 - val_loss: 7.2973e-04 - 2s/epoch - 4ms/step
# Epoch 113/512
# 539/539 - 2s - loss: 7.5206e-04 - val_loss: 7.2221e-04 - 2s/epoch - 4ms/step
# Epoch 114/512
# 539/539 - 2s - loss: 7.4526e-04 - val_loss: 7.1481e-04 - 2s/epoch - 4ms/step
# Epoch 115/512
# 539/539 - 2s - loss: 7.3792e-04 - val_loss: 7.0822e-04 - 2s/epoch - 4ms/step
# Epoch 116/512
# 539/539 - 2s - loss: 7.3073e-04 - val_loss: 7.0161e-04 - 2s/epoch - 4ms/step
# Epoch 117/512
# 539/539 - 2s - loss: 7.2393e-04 - val_loss: 6.9544e-04 - 2s/epoch - 4ms/step
# Epoch 118/512
# 539/539 - 2s - loss: 7.1771e-04 - val_loss: 6.8872e-04 - 2s/epoch - 4ms/step
# Epoch 119/512
# 539/539 - 2s - loss: 7.1132e-04 - val_loss: 6.8305e-04 - 2s/epoch - 4ms/step
# Epoch 120/512
# 539/539 - 2s - loss: 7.0596e-04 - val_loss: 6.7739e-04 - 2s/epoch - 4ms/step
# Epoch 121/512
# 539/539 - 2s - loss: 7.0029e-04 - val_loss: 6.7246e-04 - 2s/epoch - 4ms/step
# Epoch 122/512
# 539/539 - 2s - loss: 6.9446e-04 - val_loss: 6.6675e-04 - 2s/epoch - 4ms/step
# Epoch 123/512
# 539/539 - 2s - loss: 6.8945e-04 - val_loss: 6.6235e-04 - 2s/epoch - 4ms/step
# Epoch 124/512
# 539/539 - 2s - loss: 6.8552e-04 - val_loss: 6.5745e-04 - 2s/epoch - 4ms/step
# Epoch 125/512
# 539/539 - 2s - loss: 6.8061e-04 - val_loss: 6.5341e-04 - 2s/epoch - 4ms/step
# Epoch 126/512
# 539/539 - 2s - loss: 6.7634e-04 - val_loss: 6.4911e-04 - 2s/epoch - 4ms/step
# Epoch 127/512
# 539/539 - 2s - loss: 6.7251e-04 - val_loss: 6.4568e-04 - 2s/epoch - 4ms/step
# Epoch 128/512
# 539/539 - 2s - loss: 6.6790e-04 - val_loss: 6.4279e-04 - 2s/epoch - 4ms/step
# Epoch 129/512
# 539/539 - 2s - loss: 6.6408e-04 - val_loss: 6.3907e-04 - 2s/epoch - 4ms/step
# Epoch 130/512
# 539/539 - 2s - loss: 6.6088e-04 - val_loss: 6.3640e-04 - 2s/epoch - 4ms/step
# Epoch 131/512
# 539/539 - 2s - loss: 6.5844e-04 - val_loss: 6.3342e-04 - 2s/epoch - 4ms/step
# Epoch 132/512
# 539/539 - 2s - loss: 6.5617e-04 - val_loss: 6.3075e-04 - 2s/epoch - 4ms/step
# Epoch 133/512
# 539/539 - 2s - loss: 6.5316e-04 - val_loss: 6.2914e-04 - 2s/epoch - 4ms/step
# Epoch 134/512
# 539/539 - 2s - loss: 6.5134e-04 - val_loss: 6.2653e-04 - 2s/epoch - 4ms/step
# Epoch 135/512
# 539/539 - 2s - loss: 6.4890e-04 - val_loss: 6.2483e-04 - 2s/epoch - 4ms/step
# Epoch 136/512
# 539/539 - 2s - loss: 6.4690e-04 - val_loss: 6.2315e-04 - 2s/epoch - 4ms/step
# Epoch 137/512
# 539/539 - 2s - loss: 6.4567e-04 - val_loss: 6.2180e-04 - 2s/epoch - 4ms/step
# Epoch 138/512
# 539/539 - 2s - loss: 6.4398e-04 - val_loss: 6.2000e-04 - 2s/epoch - 4ms/step
# Epoch 139/512
# 539/539 - 2s - loss: 6.4249e-04 - val_loss: 6.1944e-04 - 2s/epoch - 4ms/step
# Epoch 140/512
# 539/539 - 2s - loss: 6.4112e-04 - val_loss: 6.1818e-04 - 2s/epoch - 4ms/step
# Epoch 141/512
# 539/539 - 2s - loss: 6.3967e-04 - val_loss: 6.1686e-04 - 2s/epoch - 4ms/step
# Epoch 142/512
# 539/539 - 2s - loss: 6.3833e-04 - val_loss: 6.1573e-04 - 2s/epoch - 4ms/step
# Epoch 143/512
# 539/539 - 2s - loss: 6.3851e-04 - val_loss: 6.1469e-04 - 2s/epoch - 4ms/step
# Epoch 144/512
# 539/539 - 2s - loss: 6.3703e-04 - val_loss: 6.1383e-04 - 2s/epoch - 4ms/step
# Epoch 145/512
# 539/539 - 2s - loss: 6.3552e-04 - val_loss: 6.1296e-04 - 2s/epoch - 4ms/step
# Epoch 146/512
# 539/539 - 2s - loss: 6.3436e-04 - val_loss: 6.1222e-04 - 2s/epoch - 4ms/step
# Epoch 147/512
# 539/539 - 2s - loss: 6.3349e-04 - val_loss: 6.1125e-04 - 2s/epoch - 4ms/step
# Epoch 148/512
# 539/539 - 2s - loss: 6.3275e-04 - val_loss: 6.1059e-04 - 2s/epoch - 4ms/step
# Epoch 149/512
# 539/539 - 2s - loss: 6.3343e-04 - val_loss: 6.0990e-04 - 2s/epoch - 4ms/step
# Epoch 150/512
# 539/539 - 2s - loss: 6.3070e-04 - val_loss: 6.0934e-04 - 2s/epoch - 4ms/step
# Epoch 151/512
# 539/539 - 2s - loss: 6.3065e-04 - val_loss: 6.0823e-04 - 2s/epoch - 4ms/step
# Epoch 152/512
# 539/539 - 2s - loss: 6.2964e-04 - val_loss: 6.0776e-04 - 2s/epoch - 4ms/step
# Epoch 153/512
# 539/539 - 2s - loss: 6.2848e-04 - val_loss: 6.0710e-04 - 2s/epoch - 4ms/step
# Epoch 154/512
# 539/539 - 2s - loss: 6.2801e-04 - val_loss: 6.0649e-04 - 2s/epoch - 4ms/step
# Epoch 155/512
# 539/539 - 2s - loss: 6.2750e-04 - val_loss: 6.0640e-04 - 2s/epoch - 4ms/step
# Epoch 156/512
# 539/539 - 2s - loss: 6.2751e-04 - val_loss: 6.0526e-04 - 2s/epoch - 4ms/step
# Epoch 157/512
# 539/539 - 2s - loss: 6.2635e-04 - val_loss: 6.0463e-04 - 2s/epoch - 4ms/step
# Epoch 158/512
# 539/539 - 2s - loss: 6.2580e-04 - val_loss: 6.0376e-04 - 2s/epoch - 4ms/step
# Epoch 159/512
# 539/539 - 2s - loss: 6.2536e-04 - val_loss: 6.0355e-04 - 2s/epoch - 4ms/step
# Epoch 160/512
# 539/539 - 2s - loss: 6.2467e-04 - val_loss: 6.0303e-04 - 2s/epoch - 4ms/step
# Epoch 161/512
# 539/539 - 2s - loss: 6.2389e-04 - val_loss: 6.0218e-04 - 2s/epoch - 4ms/step
# Epoch 162/512
# 539/539 - 2s - loss: 6.2295e-04 - val_loss: 6.0167e-04 - 2s/epoch - 4ms/step
# Epoch 163/512
# 539/539 - 2s - loss: 6.2249e-04 - val_loss: 6.0159e-04 - 2s/epoch - 4ms/step
# Epoch 164/512
# 539/539 - 2s - loss: 6.2169e-04 - val_loss: 6.0068e-04 - 2s/epoch - 4ms/step
# Epoch 165/512
# 539/539 - 2s - loss: 6.2200e-04 - val_loss: 6.0002e-04 - 2s/epoch - 4ms/step
# Epoch 166/512
# 539/539 - 2s - loss: 6.2036e-04 - val_loss: 5.9947e-04 - 2s/epoch - 4ms/step
# Epoch 167/512
# 539/539 - 2s - loss: 6.2012e-04 - val_loss: 5.9876e-04 - 2s/epoch - 4ms/step
# Epoch 168/512
# 539/539 - 2s - loss: 6.1981e-04 - val_loss: 5.9850e-04 - 2s/epoch - 4ms/step
# Epoch 169/512
# 539/539 - 2s - loss: 6.1921e-04 - val_loss: 5.9778e-04 - 2s/epoch - 4ms/step
# Epoch 170/512
# 539/539 - 2s - loss: 6.1721e-04 - val_loss: 5.9726e-04 - 2s/epoch - 4ms/step
# Epoch 171/512
# 539/539 - 2s - loss: 6.1796e-04 - val_loss: 5.9706e-04 - 2s/epoch - 4ms/step
# Epoch 172/512
# 539/539 - 2s - loss: 6.1697e-04 - val_loss: 5.9636e-04 - 2s/epoch - 4ms/step
# Epoch 173/512
# 539/539 - 2s - loss: 6.1702e-04 - val_loss: 5.9581e-04 - 2s/epoch - 4ms/step
# Epoch 174/512
# 539/539 - 2s - loss: 6.1658e-04 - val_loss: 5.9557e-04 - 2s/epoch - 4ms/step
# Epoch 175/512
# 539/539 - 2s - loss: 6.1560e-04 - val_loss: 5.9489e-04 - 2s/epoch - 4ms/step
# Epoch 176/512
# 539/539 - 2s - loss: 6.1612e-04 - val_loss: 5.9462e-04 - 2s/epoch - 4ms/step
# Epoch 177/512
# 539/539 - 2s - loss: 6.1468e-04 - val_loss: 5.9393e-04 - 2s/epoch - 4ms/step
# Epoch 178/512
# 539/539 - 2s - loss: 6.1408e-04 - val_loss: 5.9338e-04 - 2s/epoch - 4ms/step
# Epoch 179/512
# 539/539 - 2s - loss: 6.1347e-04 - val_loss: 5.9326e-04 - 2s/epoch - 4ms/step
# Epoch 180/512
# 539/539 - 2s - loss: 6.1493e-04 - val_loss: 5.9267e-04 - 2s/epoch - 4ms/step
# Epoch 181/512
# 539/539 - 2s - loss: 6.1379e-04 - val_loss: 5.9219e-04 - 2s/epoch - 4ms/step
# Epoch 182/512
# 539/539 - 2s - loss: 6.1292e-04 - val_loss: 5.9183e-04 - 2s/epoch - 4ms/step
# Epoch 183/512
# 539/539 - 2s - loss: 6.1251e-04 - val_loss: 5.9133e-04 - 2s/epoch - 4ms/step
# Epoch 184/512
# 539/539 - 2s - loss: 6.1175e-04 - val_loss: 5.9086e-04 - 2s/epoch - 4ms/step
# Epoch 185/512
# 539/539 - 2s - loss: 6.1036e-04 - val_loss: 5.9034e-04 - 2s/epoch - 4ms/step
# Epoch 186/512
# 539/539 - 2s - loss: 6.1064e-04 - val_loss: 5.9003e-04 - 2s/epoch - 4ms/step
# Epoch 187/512
# 539/539 - 2s - loss: 6.1041e-04 - val_loss: 5.8964e-04 - 2s/epoch - 4ms/step
# Epoch 188/512
# 539/539 - 2s - loss: 6.1049e-04 - val_loss: 5.8910e-04 - 2s/epoch - 4ms/step
# Epoch 189/512
# 539/539 - 2s - loss: 6.0975e-04 - val_loss: 5.8907e-04 - 2s/epoch - 4ms/step
# Epoch 190/512
# 539/539 - 2s - loss: 6.0894e-04 - val_loss: 5.8840e-04 - 2s/epoch - 4ms/step
# Epoch 191/512
# 539/539 - 2s - loss: 6.0864e-04 - val_loss: 5.8793e-04 - 2s/epoch - 4ms/step
# Epoch 192/512
# 539/539 - 2s - loss: 6.0795e-04 - val_loss: 5.8751e-04 - 2s/epoch - 4ms/step
# Epoch 193/512
# 539/539 - 2s - loss: 6.0807e-04 - val_loss: 5.8724e-04 - 2s/epoch - 4ms/step
# Epoch 194/512
# 539/539 - 2s - loss: 6.0699e-04 - val_loss: 5.8689e-04 - 2s/epoch - 4ms/step
# Epoch 195/512
# 539/539 - 2s - loss: 6.0629e-04 - val_loss: 5.8637e-04 - 2s/epoch - 4ms/step
# Epoch 196/512
# 539/539 - 2s - loss: 6.0812e-04 - val_loss: 5.8591e-04 - 2s/epoch - 4ms/step
# Epoch 197/512
# 539/539 - 2s - loss: 6.0638e-04 - val_loss: 5.8567e-04 - 2s/epoch - 4ms/step
# Epoch 198/512
# 539/539 - 2s - loss: 6.0628e-04 - val_loss: 5.8547e-04 - 2s/epoch - 4ms/step
# Epoch 199/512
# 539/539 - 2s - loss: 6.0567e-04 - val_loss: 5.8505e-04 - 2s/epoch - 4ms/step
# Epoch 200/512
# 539/539 - 2s - loss: 6.0464e-04 - val_loss: 5.8443e-04 - 2s/epoch - 4ms/step
# Epoch 201/512
# 539/539 - 2s - loss: 6.0538e-04 - val_loss: 5.8420e-04 - 2s/epoch - 4ms/step
# Epoch 202/512
# 539/539 - 2s - loss: 6.0425e-04 - val_loss: 5.8384e-04 - 2s/epoch - 4ms/step
# Epoch 203/512
# 539/539 - 2s - loss: 6.0415e-04 - val_loss: 5.8356e-04 - 2s/epoch - 4ms/step
# Epoch 204/512
# 539/539 - 2s - loss: 6.0358e-04 - val_loss: 5.8303e-04 - 2s/epoch - 4ms/step
# Epoch 205/512
# 539/539 - 2s - loss: 6.0297e-04 - val_loss: 5.8305e-04 - 2s/epoch - 4ms/step
# Epoch 206/512
# 539/539 - 2s - loss: 6.0237e-04 - val_loss: 5.8247e-04 - 2s/epoch - 4ms/step
# Epoch 207/512
# 539/539 - 2s - loss: 6.0315e-04 - val_loss: 5.8209e-04 - 2s/epoch - 4ms/step
# Epoch 208/512
# 539/539 - 2s - loss: 6.0222e-04 - val_loss: 5.8179e-04 - 2s/epoch - 4ms/step
# Epoch 209/512
# 539/539 - 2s - loss: 6.0137e-04 - val_loss: 5.8136e-04 - 2s/epoch - 4ms/step
# Epoch 210/512
# 539/539 - 2s - loss: 6.0192e-04 - val_loss: 5.8100e-04 - 2s/epoch - 4ms/step
# Epoch 211/512
# 539/539 - 2s - loss: 6.0106e-04 - val_loss: 5.8079e-04 - 2s/epoch - 4ms/step
# Epoch 212/512
# 539/539 - 2s - loss: 6.0151e-04 - val_loss: 5.8045e-04 - 2s/epoch - 4ms/step
# Epoch 213/512
# 539/539 - 2s - loss: 5.9983e-04 - val_loss: 5.8011e-04 - 2s/epoch - 4ms/step
# Epoch 214/512
# 539/539 - 2s - loss: 6.0010e-04 - val_loss: 5.7978e-04 - 2s/epoch - 4ms/step
# Epoch 215/512
# 539/539 - 2s - loss: 6.0054e-04 - val_loss: 5.7958e-04 - 2s/epoch - 4ms/step
# Epoch 216/512
# 539/539 - 2s - loss: 5.9938e-04 - val_loss: 5.7916e-04 - 2s/epoch - 4ms/step
# Epoch 217/512
# 539/539 - 2s - loss: 5.9873e-04 - val_loss: 5.7901e-04 - 2s/epoch - 4ms/step
# Epoch 218/512
# 539/539 - 2s - loss: 5.9912e-04 - val_loss: 5.7852e-04 - 2s/epoch - 4ms/step
# Epoch 219/512
# 539/539 - 2s - loss: 5.9860e-04 - val_loss: 5.7837e-04 - 2s/epoch - 4ms/step
# Epoch 220/512
# 539/539 - 2s - loss: 5.9863e-04 - val_loss: 5.7831e-04 - 2s/epoch - 4ms/step
# Epoch 221/512
# 539/539 - 2s - loss: 5.9768e-04 - val_loss: 5.7804e-04 - 2s/epoch - 4ms/step
# Epoch 222/512
# 539/539 - 2s - loss: 5.9786e-04 - val_loss: 5.7744e-04 - 2s/epoch - 4ms/step
# Epoch 223/512
# 539/539 - 2s - loss: 5.9733e-04 - val_loss: 5.7715e-04 - 2s/epoch - 4ms/step
# Epoch 224/512
# 539/539 - 2s - loss: 5.9692e-04 - val_loss: 5.7691e-04 - 2s/epoch - 4ms/step
# Epoch 225/512
# 539/539 - 2s - loss: 5.9595e-04 - val_loss: 5.7647e-04 - 2s/epoch - 4ms/step
# Epoch 226/512
# 539/539 - 2s - loss: 5.9583e-04 - val_loss: 5.7618e-04 - 2s/epoch - 4ms/step
# Epoch 227/512
# 539/539 - 2s - loss: 5.9641e-04 - val_loss: 5.7600e-04 - 2s/epoch - 4ms/step
# Epoch 228/512
# 539/539 - 2s - loss: 5.9522e-04 - val_loss: 5.7563e-04 - 2s/epoch - 4ms/step
# Epoch 229/512
# 539/539 - 2s - loss: 5.9476e-04 - val_loss: 5.7545e-04 - 2s/epoch - 4ms/step
# Epoch 230/512
# 539/539 - 2s - loss: 5.9503e-04 - val_loss: 5.7511e-04 - 2s/epoch - 4ms/step
# Epoch 231/512
# 539/539 - 2s - loss: 5.9518e-04 - val_loss: 5.7485e-04 - 2s/epoch - 4ms/step
# Epoch 232/512
# 539/539 - 2s - loss: 5.9482e-04 - val_loss: 5.7459e-04 - 2s/epoch - 4ms/step
# Epoch 233/512
# 539/539 - 2s - loss: 5.9467e-04 - val_loss: 5.7441e-04 - 2s/epoch - 4ms/step
# Epoch 234/512
# 539/539 - 2s - loss: 5.9423e-04 - val_loss: 5.7412e-04 - 2s/epoch - 4ms/step
# Epoch 235/512
# 539/539 - 2s - loss: 5.9350e-04 - val_loss: 5.7386e-04 - 2s/epoch - 4ms/step
# Epoch 236/512
# 539/539 - 2s - loss: 5.9374e-04 - val_loss: 5.7358e-04 - 2s/epoch - 4ms/step
# Epoch 237/512
# 539/539 - 2s - loss: 5.9329e-04 - val_loss: 5.7333e-04 - 2s/epoch - 4ms/step
# Epoch 238/512
# 539/539 - 2s - loss: 5.9331e-04 - val_loss: 5.7311e-04 - 2s/epoch - 4ms/step
# Epoch 239/512
# 539/539 - 2s - loss: 5.9263e-04 - val_loss: 5.7287e-04 - 2s/epoch - 4ms/step
# Epoch 240/512
# 539/539 - 2s - loss: 5.9206e-04 - val_loss: 5.7260e-04 - 2s/epoch - 4ms/step
# Epoch 241/512
# 539/539 - 2s - loss: 5.9242e-04 - val_loss: 5.7241e-04 - 2s/epoch - 4ms/step
# Epoch 242/512
# 539/539 - 2s - loss: 5.9175e-04 - val_loss: 5.7213e-04 - 2s/epoch - 4ms/step
# Epoch 243/512
# 539/539 - 2s - loss: 5.9226e-04 - val_loss: 5.7195e-04 - 2s/epoch - 4ms/step
# Epoch 244/512
# 539/539 - 2s - loss: 5.9164e-04 - val_loss: 5.7170e-04 - 2s/epoch - 4ms/step
# Epoch 245/512
# 539/539 - 2s - loss: 5.9096e-04 - val_loss: 5.7147e-04 - 2s/epoch - 4ms/step
# Epoch 246/512
# 539/539 - 2s - loss: 5.9085e-04 - val_loss: 5.7125e-04 - 2s/epoch - 4ms/step
# Epoch 247/512
# 539/539 - 2s - loss: 5.9003e-04 - val_loss: 5.7101e-04 - 2s/epoch - 4ms/step
# Epoch 248/512
# 539/539 - 2s - loss: 5.9070e-04 - val_loss: 5.7078e-04 - 2s/epoch - 4ms/step
# Epoch 249/512
# 539/539 - 2s - loss: 5.9038e-04 - val_loss: 5.7054e-04 - 2s/epoch - 4ms/step
# Epoch 250/512
# 539/539 - 2s - loss: 5.9004e-04 - val_loss: 5.7033e-04 - 2s/epoch - 4ms/step
# Epoch 251/512
# 539/539 - 2s - loss: 5.8922e-04 - val_loss: 5.7011e-04 - 2s/epoch - 4ms/step
# Epoch 252/512
# 539/539 - 2s - loss: 5.9014e-04 - val_loss: 5.7002e-04 - 2s/epoch - 4ms/step
# Epoch 253/512
# 539/539 - 2s - loss: 5.8931e-04 - val_loss: 5.6970e-04 - 2s/epoch - 4ms/step
# Epoch 254/512
# 539/539 - 2s - loss: 5.8971e-04 - val_loss: 5.6951e-04 - 2s/epoch - 4ms/step
# Epoch 255/512
# 539/539 - 2s - loss: 5.8850e-04 - val_loss: 5.6924e-04 - 2s/epoch - 4ms/step
# Epoch 256/512
# 539/539 - 2s - loss: 5.8882e-04 - val_loss: 5.6905e-04 - 2s/epoch - 4ms/step
# Epoch 257/512
# 539/539 - 2s - loss: 5.8817e-04 - val_loss: 5.6901e-04 - 2s/epoch - 4ms/step
# Epoch 258/512
# 539/539 - 2s - loss: 5.8845e-04 - val_loss: 5.6865e-04 - 2s/epoch - 4ms/step
# Epoch 259/512
# 539/539 - 2s - loss: 5.8814e-04 - val_loss: 5.6842e-04 - 2s/epoch - 4ms/step
# Epoch 260/512
# 539/539 - 2s - loss: 5.8720e-04 - val_loss: 5.6821e-04 - 2s/epoch - 4ms/step
# Epoch 261/512
# 539/539 - 2s - loss: 5.8727e-04 - val_loss: 5.6811e-04 - 2s/epoch - 4ms/step
# Epoch 262/512
# 539/539 - 2s - loss: 5.8713e-04 - val_loss: 5.6794e-04 - 2s/epoch - 4ms/step
# Epoch 263/512
# 539/539 - 2s - loss: 5.8689e-04 - val_loss: 5.6785e-04 - 2s/epoch - 4ms/step
# Epoch 264/512
# 539/539 - 2s - loss: 5.8684e-04 - val_loss: 5.6739e-04 - 2s/epoch - 4ms/step
# Epoch 265/512
# 539/539 - 2s - loss: 5.8629e-04 - val_loss: 5.6721e-04 - 2s/epoch - 4ms/step
# Epoch 266/512
# 539/539 - 2s - loss: 5.8657e-04 - val_loss: 5.6713e-04 - 2s/epoch - 4ms/step
# Epoch 267/512
# 539/539 - 2s - loss: 5.8726e-04 - val_loss: 5.6679e-04 - 2s/epoch - 4ms/step
# Epoch 268/512
# 539/539 - 2s - loss: 5.8643e-04 - val_loss: 5.6662e-04 - 2s/epoch - 4ms/step
# Epoch 269/512
# 539/539 - 2s - loss: 5.8585e-04 - val_loss: 5.6641e-04 - 2s/epoch - 4ms/step
# Epoch 270/512
# 539/539 - 2s - loss: 5.8590e-04 - val_loss: 5.6628e-04 - 2s/epoch - 4ms/step
# Epoch 271/512
# 539/539 - 2s - loss: 5.8506e-04 - val_loss: 5.6603e-04 - 2s/epoch - 4ms/step
# Epoch 272/512
# 539/539 - 2s - loss: 5.8585e-04 - val_loss: 5.6586e-04 - 2s/epoch - 4ms/step
# Epoch 273/512
# 539/539 - 2s - loss: 5.8565e-04 - val_loss: 5.6566e-04 - 2s/epoch - 4ms/step
# Epoch 274/512
# 539/539 - 2s - loss: 5.8460e-04 - val_loss: 5.6549e-04 - 2s/epoch - 4ms/step
# Epoch 275/512
# 539/539 - 2s - loss: 5.8529e-04 - val_loss: 5.6533e-04 - 2s/epoch - 4ms/step
# Epoch 276/512
# 539/539 - 2s - loss: 5.8393e-04 - val_loss: 5.6513e-04 - 2s/epoch - 4ms/step
# Epoch 277/512
# 539/539 - 2s - loss: 5.8564e-04 - val_loss: 5.6499e-04 - 2s/epoch - 4ms/step
# Epoch 278/512
# 539/539 - 2s - loss: 5.8524e-04 - val_loss: 5.6480e-04 - 2s/epoch - 4ms/step
# Epoch 279/512
# 539/539 - 2s - loss: 5.8371e-04 - val_loss: 5.6460e-04 - 2s/epoch - 4ms/step
# Epoch 280/512
# 539/539 - 2s - loss: 5.8390e-04 - val_loss: 5.6442e-04 - 2s/epoch - 4ms/step
# Epoch 281/512
# 539/539 - 2s - loss: 5.8338e-04 - val_loss: 5.6430e-04 - 2s/epoch - 4ms/step
# Epoch 282/512
# 539/539 - 2s - loss: 5.8395e-04 - val_loss: 5.6408e-04 - 2s/epoch - 4ms/step
# Epoch 283/512
# 539/539 - 2s - loss: 5.8335e-04 - val_loss: 5.6398e-04 - 2s/epoch - 4ms/step
# Epoch 284/512
# 539/539 - 2s - loss: 5.8284e-04 - val_loss: 5.6382e-04 - 2s/epoch - 4ms/step
# Epoch 285/512
# 539/539 - 2s - loss: 5.8240e-04 - val_loss: 5.6353e-04 - 2s/epoch - 4ms/step
# Epoch 286/512
# 539/539 - 2s - loss: 5.8287e-04 - val_loss: 5.6336e-04 - 2s/epoch - 4ms/step
# Epoch 287/512
# 539/539 - 2s - loss: 5.8300e-04 - val_loss: 5.6325e-04 - 2s/epoch - 4ms/step
# Epoch 288/512
# 539/539 - 2s - loss: 5.8218e-04 - val_loss: 5.6302e-04 - 2s/epoch - 4ms/step
# Epoch 289/512
# 539/539 - 2s - loss: 5.8152e-04 - val_loss: 5.6286e-04 - 2s/epoch - 4ms/step
# Epoch 290/512
# 539/539 - 2s - loss: 5.8185e-04 - val_loss: 5.6270e-04 - 2s/epoch - 4ms/step
# Epoch 291/512
# 539/539 - 2s - loss: 5.8149e-04 - val_loss: 5.6253e-04 - 2s/epoch - 4ms/step
# Epoch 292/512
# 539/539 - 2s - loss: 5.8152e-04 - val_loss: 5.6242e-04 - 2s/epoch - 4ms/step
# Epoch 293/512
# 539/539 - 2s - loss: 5.8136e-04 - val_loss: 5.6221e-04 - 2s/epoch - 4ms/step
# Epoch 294/512
# 539/539 - 2s - loss: 5.8190e-04 - val_loss: 5.6216e-04 - 2s/epoch - 4ms/step
# Epoch 295/512
# 539/539 - 2s - loss: 5.8167e-04 - val_loss: 5.6194e-04 - 2s/epoch - 4ms/step
# Epoch 296/512
# 539/539 - 2s - loss: 5.8085e-04 - val_loss: 5.6179e-04 - 2s/epoch - 4ms/step
# Epoch 297/512
# 539/539 - 2s - loss: 5.8071e-04 - val_loss: 5.6158e-04 - 2s/epoch - 4ms/step
# Epoch 298/512
# 539/539 - 2s - loss: 5.8120e-04 - val_loss: 5.6145e-04 - 2s/epoch - 4ms/step
# Epoch 299/512
# 539/539 - 2s - loss: 5.8070e-04 - val_loss: 5.6127e-04 - 2s/epoch - 4ms/step
# Epoch 300/512
# 539/539 - 2s - loss: 5.8064e-04 - val_loss: 5.6119e-04 - 2s/epoch - 4ms/step
# Epoch 301/512
# 539/539 - 2s - loss: 5.7996e-04 - val_loss: 5.6120e-04 - 2s/epoch - 4ms/step
# Epoch 302/512
# 539/539 - 2s - loss: 5.8042e-04 - val_loss: 5.6088e-04 - 2s/epoch - 4ms/step
# Epoch 303/512
# 539/539 - 2s - loss: 5.7995e-04 - val_loss: 5.6066e-04 - 2s/epoch - 4ms/step
# Epoch 304/512
# 539/539 - 2s - loss: 5.8023e-04 - val_loss: 5.6052e-04 - 2s/epoch - 4ms/step
# Epoch 305/512
# 539/539 - 2s - loss: 5.7945e-04 - val_loss: 5.6042e-04 - 2s/epoch - 4ms/step
# Epoch 306/512
# 539/539 - 2s - loss: 5.7927e-04 - val_loss: 5.6022e-04 - 2s/epoch - 4ms/step
# Epoch 307/512
# 539/539 - 2s - loss: 5.7913e-04 - val_loss: 5.6009e-04 - 2s/epoch - 4ms/step
# Epoch 308/512
# 539/539 - 2s - loss: 5.7965e-04 - val_loss: 5.5993e-04 - 2s/epoch - 4ms/step
# Epoch 309/512
# 539/539 - 2s - loss: 5.7904e-04 - val_loss: 5.5983e-04 - 2s/epoch - 4ms/step
# Epoch 310/512
# 539/539 - 2s - loss: 5.7993e-04 - val_loss: 5.5965e-04 - 2s/epoch - 4ms/step
# Epoch 311/512
# 539/539 - 2s - loss: 5.7851e-04 - val_loss: 5.5955e-04 - 2s/epoch - 4ms/step
# Epoch 312/512
# 539/539 - 2s - loss: 5.7916e-04 - val_loss: 5.5944e-04 - 2s/epoch - 4ms/step
# Epoch 313/512
# 539/539 - 2s - loss: 5.7841e-04 - val_loss: 5.5933e-04 - 2s/epoch - 4ms/step
# Epoch 314/512
# 539/539 - 2s - loss: 5.7867e-04 - val_loss: 5.5906e-04 - 2s/epoch - 4ms/step
# Epoch 315/512
# 539/539 - 2s - loss: 5.7866e-04 - val_loss: 5.5892e-04 - 2s/epoch - 4ms/step
# Epoch 316/512
# 539/539 - 2s - loss: 5.7816e-04 - val_loss: 5.5881e-04 - 2s/epoch - 4ms/step
# Epoch 317/512
# 539/539 - 2s - loss: 5.7814e-04 - val_loss: 5.5865e-04 - 2s/epoch - 4ms/step
# Epoch 318/512
# 539/539 - 2s - loss: 5.7749e-04 - val_loss: 5.5851e-04 - 2s/epoch - 4ms/step
# Epoch 319/512
# 539/539 - 2s - loss: 5.7748e-04 - val_loss: 5.5837e-04 - 2s/epoch - 4ms/step
# Epoch 320/512
# 539/539 - 2s - loss: 5.7744e-04 - val_loss: 5.5835e-04 - 2s/epoch - 4ms/step
# Epoch 321/512
# 539/539 - 2s - loss: 5.7688e-04 - val_loss: 5.5811e-04 - 2s/epoch - 4ms/step
# Epoch 322/512
# 539/539 - 2s - loss: 5.7704e-04 - val_loss: 5.5796e-04 - 2s/epoch - 4ms/step
# Epoch 323/512
# 539/539 - 2s - loss: 5.7714e-04 - val_loss: 5.5783e-04 - 2s/epoch - 4ms/step
# Epoch 324/512
# 539/539 - 2s - loss: 5.7752e-04 - val_loss: 5.5774e-04 - 2s/epoch - 4ms/step
# Epoch 325/512
# 539/539 - 2s - loss: 5.7677e-04 - val_loss: 5.5758e-04 - 2s/epoch - 4ms/step
# Epoch 326/512
# 539/539 - 2s - loss: 5.7758e-04 - val_loss: 5.5742e-04 - 2s/epoch - 4ms/step
# Epoch 327/512
# 539/539 - 2s - loss: 5.7709e-04 - val_loss: 5.5737e-04 - 2s/epoch - 4ms/step
# Epoch 328/512
# 539/539 - 2s - loss: 5.7655e-04 - val_loss: 5.5715e-04 - 2s/epoch - 4ms/step
# Epoch 329/512
# 539/539 - 2s - loss: 5.7631e-04 - val_loss: 5.5702e-04 - 2s/epoch - 4ms/step
# Epoch 330/512
# 539/539 - 2s - loss: 5.7600e-04 - val_loss: 5.5694e-04 - 2s/epoch - 4ms/step
# Epoch 331/512
# 539/539 - 2s - loss: 5.7649e-04 - val_loss: 5.5678e-04 - 2s/epoch - 4ms/step
# Epoch 332/512
# 539/539 - 2s - loss: 5.7546e-04 - val_loss: 5.5665e-04 - 2s/epoch - 4ms/step
# Epoch 333/512
# 539/539 - 2s - loss: 5.7554e-04 - val_loss: 5.5651e-04 - 2s/epoch - 4ms/step
# Epoch 334/512
# 539/539 - 2s - loss: 5.7545e-04 - val_loss: 5.5646e-04 - 2s/epoch - 4ms/step
# Epoch 335/512
# 539/539 - 2s - loss: 5.7572e-04 - val_loss: 5.5628e-04 - 2s/epoch - 4ms/step
# Epoch 336/512
# 539/539 - 2s - loss: 5.7495e-04 - val_loss: 5.5616e-04 - 2s/epoch - 4ms/step
# Epoch 337/512
# 539/539 - 2s - loss: 5.7467e-04 - val_loss: 5.5599e-04 - 2s/epoch - 4ms/step
# Epoch 338/512
# 539/539 - 2s - loss: 5.7434e-04 - val_loss: 5.5598e-04 - 2s/epoch - 4ms/step
# Epoch 339/512
# 539/539 - 2s - loss: 5.7437e-04 - val_loss: 5.5574e-04 - 2s/epoch - 4ms/step
# Epoch 340/512
# 539/539 - 2s - loss: 5.7443e-04 - val_loss: 5.5561e-04 - 2s/epoch - 4ms/step
# Epoch 341/512
# 539/539 - 2s - loss: 5.7427e-04 - val_loss: 5.5548e-04 - 2s/epoch - 4ms/step
# Epoch 342/512
# 539/539 - 2s - loss: 5.7489e-04 - val_loss: 5.5536e-04 - 2s/epoch - 4ms/step
# Epoch 343/512
# 539/539 - 2s - loss: 5.7343e-04 - val_loss: 5.5528e-04 - 2s/epoch - 4ms/step
# Epoch 344/512
# 539/539 - 2s - loss: 5.7436e-04 - val_loss: 5.5510e-04 - 2s/epoch - 4ms/step
# Epoch 345/512
# 539/539 - 2s - loss: 5.7392e-04 - val_loss: 5.5498e-04 - 2s/epoch - 4ms/step
# Epoch 346/512
# 539/539 - 2s - loss: 5.7386e-04 - val_loss: 5.5486e-04 - 2s/epoch - 4ms/step
# Epoch 347/512
# 539/539 - 2s - loss: 5.7390e-04 - val_loss: 5.5479e-04 - 2s/epoch - 4ms/step
# Epoch 348/512
# 539/539 - 2s - loss: 5.7332e-04 - val_loss: 5.5462e-04 - 2s/epoch - 4ms/step
# Epoch 349/512
# 539/539 - 2s - loss: 5.7378e-04 - val_loss: 5.5451e-04 - 2s/epoch - 4ms/step
# Epoch 350/512
# 539/539 - 2s - loss: 5.7383e-04 - val_loss: 5.5440e-04 - 2s/epoch - 4ms/step
# Epoch 351/512
# 539/539 - 2s - loss: 5.7334e-04 - val_loss: 5.5428e-04 - 2s/epoch - 4ms/step
# Epoch 352/512
# 539/539 - 2s - loss: 5.7342e-04 - val_loss: 5.5414e-04 - 2s/epoch - 4ms/step
# Epoch 353/512
# 539/539 - 2s - loss: 5.7282e-04 - val_loss: 5.5403e-04 - 2s/epoch - 4ms/step
# Epoch 354/512
# 539/539 - 2s - loss: 5.7297e-04 - val_loss: 5.5390e-04 - 2s/epoch - 4ms/step
# Epoch 355/512
# 539/539 - 2s - loss: 5.7250e-04 - val_loss: 5.5378e-04 - 2s/epoch - 4ms/step
# Epoch 356/512
# 539/539 - 2s - loss: 5.7276e-04 - val_loss: 5.5366e-04 - 2s/epoch - 4ms/step
# Epoch 357/512
# 539/539 - 2s - loss: 5.7229e-04 - val_loss: 5.5373e-04 - 2s/epoch - 4ms/step
# Epoch 358/512
# 539/539 - 2s - loss: 5.7251e-04 - val_loss: 5.5341e-04 - 2s/epoch - 4ms/step
# Epoch 359/512
# 539/539 - 2s - loss: 5.7201e-04 - val_loss: 5.5349e-04 - 2s/epoch - 4ms/step
# Epoch 360/512
# 539/539 - 2s - loss: 5.7201e-04 - val_loss: 5.5320e-04 - 2s/epoch - 4ms/step
# Epoch 361/512
# 539/539 - 2s - loss: 5.7221e-04 - val_loss: 5.5307e-04 - 2s/epoch - 4ms/step
# Epoch 362/512
# 539/539 - 2s - loss: 5.7182e-04 - val_loss: 5.5305e-04 - 2s/epoch - 4ms/step
# Epoch 363/512
# 539/539 - 2s - loss: 5.7177e-04 - val_loss: 5.5283e-04 - 2s/epoch - 4ms/step
# Epoch 364/512
# 539/539 - 2s - loss: 5.7237e-04 - val_loss: 5.5272e-04 - 2s/epoch - 4ms/step
# Epoch 365/512
# 539/539 - 2s - loss: 5.7101e-04 - val_loss: 5.5260e-04 - 2s/epoch - 4ms/step
# Epoch 366/512
# 539/539 - 2s - loss: 5.7166e-04 - val_loss: 5.5250e-04 - 2s/epoch - 4ms/step
# Epoch 367/512
# 539/539 - 2s - loss: 5.7091e-04 - val_loss: 5.5238e-04 - 2s/epoch - 4ms/step
# Epoch 368/512
# 539/539 - 2s - loss: 5.7060e-04 - val_loss: 5.5231e-04 - 2s/epoch - 4ms/step
# Epoch 369/512
# 539/539 - 2s - loss: 5.7105e-04 - val_loss: 5.5220e-04 - 2s/epoch - 4ms/step
# Epoch 370/512
# 539/539 - 2s - loss: 5.7058e-04 - val_loss: 5.5205e-04 - 2s/epoch - 4ms/step
# Epoch 371/512
# 539/539 - 2s - loss: 5.7026e-04 - val_loss: 5.5192e-04 - 2s/epoch - 4ms/step
# Epoch 372/512
# 539/539 - 2s - loss: 5.7062e-04 - val_loss: 5.5181e-04 - 2s/epoch - 4ms/step
# Epoch 373/512
# 539/539 - 2s - loss: 5.6976e-04 - val_loss: 5.5169e-04 - 2s/epoch - 4ms/step
# Epoch 374/512
# 539/539 - 2s - loss: 5.7045e-04 - val_loss: 5.5158e-04 - 2s/epoch - 4ms/step
# Epoch 375/512
# 539/539 - 2s - loss: 5.7033e-04 - val_loss: 5.5147e-04 - 2s/epoch - 4ms/step
# Epoch 376/512
# 539/539 - 2s - loss: 5.7102e-04 - val_loss: 5.5137e-04 - 2s/epoch - 4ms/step
# Epoch 377/512
# 539/539 - 2s - loss: 5.6996e-04 - val_loss: 5.5126e-04 - 2s/epoch - 4ms/step
# Epoch 378/512
# 539/539 - 2s - loss: 5.6949e-04 - val_loss: 5.5117e-04 - 2s/epoch - 4ms/step
# Epoch 379/512
# 539/539 - 2s - loss: 5.6940e-04 - val_loss: 5.5113e-04 - 2s/epoch - 4ms/step
# Epoch 380/512
# 539/539 - 2s - loss: 5.6989e-04 - val_loss: 5.5106e-04 - 2s/epoch - 4ms/step
# Epoch 381/512
# 539/539 - 2s - loss: 5.7008e-04 - val_loss: 5.5089e-04 - 2s/epoch - 4ms/step
# Epoch 382/512
# 539/539 - 2s - loss: 5.6963e-04 - val_loss: 5.5072e-04 - 2s/epoch - 4ms/step
# Epoch 383/512
# 539/539 - 2s - loss: 5.6874e-04 - val_loss: 5.5061e-04 - 2s/epoch - 4ms/step
# Epoch 384/512
# 539/539 - 2s - loss: 5.6834e-04 - val_loss: 5.5052e-04 - 2s/epoch - 4ms/step
# Epoch 385/512
# 539/539 - 2s - loss: 5.6839e-04 - val_loss: 5.5039e-04 - 2s/epoch - 4ms/step
# Epoch 386/512
# 539/539 - 2s - loss: 5.6919e-04 - val_loss: 5.5028e-04 - 2s/epoch - 4ms/step
# Epoch 387/512
# 539/539 - 2s - loss: 5.6866e-04 - val_loss: 5.5018e-04 - 2s/epoch - 4ms/step
# Epoch 388/512
# 539/539 - 2s - loss: 5.6903e-04 - val_loss: 5.5010e-04 - 2s/epoch - 4ms/step
# Epoch 389/512
# 539/539 - 2s - loss: 5.6850e-04 - val_loss: 5.4997e-04 - 2s/epoch - 4ms/step
# Epoch 390/512
# 539/539 - 2s - loss: 5.6851e-04 - val_loss: 5.4986e-04 - 2s/epoch - 4ms/step
# Epoch 391/512
# 539/539 - 2s - loss: 5.6815e-04 - val_loss: 5.4976e-04 - 2s/epoch - 4ms/step
# Epoch 392/512
# 539/539 - 2s - loss: 5.6932e-04 - val_loss: 5.4965e-04 - 2s/epoch - 4ms/step
# Epoch 393/512
# 539/539 - 2s - loss: 5.6756e-04 - val_loss: 5.4956e-04 - 2s/epoch - 4ms/step
# Epoch 394/512
# 539/539 - 2s - loss: 5.6804e-04 - val_loss: 5.4946e-04 - 2s/epoch - 4ms/step
# Epoch 395/512
# 539/539 - 2s - loss: 5.6797e-04 - val_loss: 5.4938e-04 - 2s/epoch - 4ms/step
# Epoch 396/512
# 539/539 - 2s - loss: 5.6823e-04 - val_loss: 5.4933e-04 - 2s/epoch - 4ms/step
# Epoch 397/512
# 539/539 - 2s - loss: 5.6824e-04 - val_loss: 5.4915e-04 - 2s/epoch - 4ms/step
# Epoch 398/512
# 539/539 - 2s - loss: 5.6758e-04 - val_loss: 5.4904e-04 - 2s/epoch - 4ms/step
# Epoch 399/512
# 539/539 - 2s - loss: 5.6791e-04 - val_loss: 5.4894e-04 - 2s/epoch - 4ms/step
# Epoch 400/512
# 539/539 - 2s - loss: 5.6771e-04 - val_loss: 5.4896e-04 - 2s/epoch - 4ms/step
# Epoch 401/512
# 539/539 - 2s - loss: 5.6702e-04 - val_loss: 5.4875e-04 - 2s/epoch - 4ms/step
# Epoch 402/512
# 539/539 - 2s - loss: 5.6694e-04 - val_loss: 5.4864e-04 - 2s/epoch - 4ms/step
# Epoch 403/512
# 539/539 - 2s - loss: 5.6761e-04 - val_loss: 5.4853e-04 - 2s/epoch - 4ms/step
# Epoch 404/512
# 539/539 - 2s - loss: 5.6769e-04 - val_loss: 5.4857e-04 - 2s/epoch - 4ms/step
# Epoch 405/512
# 539/539 - 2s - loss: 5.6681e-04 - val_loss: 5.4832e-04 - 2s/epoch - 4ms/step
# Epoch 406/512
# 539/539 - 2s - loss: 5.6643e-04 - val_loss: 5.4824e-04 - 2s/epoch - 4ms/step
# Epoch 407/512
# 539/539 - 2s - loss: 5.6697e-04 - val_loss: 5.4813e-04 - 2s/epoch - 4ms/step
# Epoch 408/512
# 539/539 - 2s - loss: 5.6668e-04 - val_loss: 5.4804e-04 - 2s/epoch - 4ms/step
# Epoch 409/512
# 539/539 - 2s - loss: 5.6681e-04 - val_loss: 5.4792e-04 - 2s/epoch - 4ms/step
# Epoch 410/512
# 539/539 - 2s - loss: 5.6623e-04 - val_loss: 5.4785e-04 - 2s/epoch - 4ms/step
# Epoch 411/512
# 539/539 - 2s - loss: 5.6593e-04 - val_loss: 5.4773e-04 - 2s/epoch - 4ms/step
# Epoch 412/512
# 539/539 - 2s - loss: 5.6584e-04 - val_loss: 5.4768e-04 - 2s/epoch - 4ms/step

# %%
# save model
model.save("DNN_pz.h5", save_format="h5", overwrite=True)
# predict
pred_y = model.predict(test_x)
sig_pred = pred_y
sig_truth = test_y
# Out:
#     1/12924 [..............................] - ETA: 19:41
# /root/miniconda3/envs/tf/lib/python3.10/site-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 12924/12924 [==============================] - 15s 1ms/step

# %%
print(f"Truth mean: {np.mean(sig_truth[:,0]):.3f}, std: {np.std(sig_truth[:,0]):.3f}")
# Out:
# Truth mean: 0.498, std: 0.033

# %%
range = [0.43, 0.57]

plot.plot_hist(
    [sig_truth[:, 0], sig_pred[:, 0]],
    [r"$p_{z\ truth}^{\nu\nu}$", r"$p_{z\ pred}^{\nu\nu}$"],
    r"Sig. norm. $p^{\nu\nu}_{z}$"
    + f" with RMSE: {np.sqrt(mean_squared_error(sig_truth[:,0], sig_pred[:,0])):.3f}",
    range=range,
    xlabel=r"Norm. $p_{z}$ [unit]",
)

plot.plot_loss_history(history, logx=True, logy=True)

plot.plot_2d_histogram(
    sig_truth[:, 0],
    sig_pred[:, 0],
    r"Sig. $p_{z}^{\nu\nu}$ "
    + f"with Pearson coeff: {sp.stats.pearsonr(sig_truth[:,0], sig_pred[:,0])[0]:.3f}",
    range=range,
)

time_end = time()
print(f"Time cost: {time_end - time_start:.2f} s")
# Out:
# Time cost: 966.83 s
